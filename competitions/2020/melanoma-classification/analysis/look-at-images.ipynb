# %%
import matplotlib.pyplot as plt
from os.path import join
from os import listdir
from coreml.utils.io import read_img

# %%
root = '/data/siim-isic-melanoma/processed/images/'

# %%
files = listdir(root)

# %%
for file in files[:5]:
    img = read_img(join(root, file))
    plt.imshow(img)
    plt.show()

# %%
root = '/data/siim-isic-melanoma/processed/images-200x200/'

# %%
files = listdir(root)

# %%
for file in files[:5]:
    img = read_img(join(root, file))
    plt.imshow(img)
    plt.show()
